# %% [markdown]
# The DGS data that I obtained comes with .eaf files that have annotations that I plan to use to extract key
# parts of the videos with relevant words. My first objective is to determine the relevant tiers and then to get
# word counts to determine which words would be best for use in a small DGS translation prototype.
#
# The archive can be found at:
#
# https://www.sign-lang.uni-hamburg.de/dgs-korpus/

# %%
import pandas as pd
import pympi
import os
import re
import json
from moviepy import VideoFileClip

"""
loads in the .eaf files and prints the tier names.
"""

directory = '../data/raw/dialogues'
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f)) and f.endswith('.eaf')]

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    tier_names = eaf.get_tier_names()
    print(tier_names)
# Out:
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_B', 'Translation_into_English_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Moderator'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_B', 'Translation_into_English_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Moderator', 'Translation_into_English_Mod'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Translation_into_English_B', 'Deutsche_Übersetzung_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B'])
# dict_keys(['Deutsche_Übersetzung_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Translation_into_English_A', 'Deutsche_Übersetzung_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Translation_into_English_B', 'Moderator', 'Translation_into_English_Mod'])
# dict_keys(['Deutsche_Übersetzung_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Translation_into_English_A', 'Deutsche_Übersetzung_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Translation_into_English_B'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Translation_into_English_B', 'Deutsche_Übersetzung_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Moderator', 'Translation_into_English_Mod'])
# dict_keys(['Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Deutsche_Übersetzung_B', 'Translation_into_English_B', 'Moderator', 'Translation_into_English_Mod'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_B', 'Translation_into_English_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Moderator', 'Translation_into_English_Mod'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_B', 'Translation_into_English_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_B', 'Translation_into_English_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Moderator', 'Translation_into_English_Mod'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Lexem_Gebärde_l_A', 'Lexeme_Sign_l_A', 'Gebärde_l_A', 'Sign_l_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Translation_into_English_B', 'Moderator'])
# dict_keys(['Deutsche_Übersetzung_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Mundbild_Mundgestik_A', 'Translation_into_English_A', 'Deutsche_Übersetzung_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Translation_into_English_B', 'Moderator', 'Translation_into_English_Mod'])
# dict_keys(['Deutsche_Übersetzung_A', 'Translation_into_English_A', 'Lexem_Gebärde_r_A', 'Lexeme_Sign_r_A', 'Gebärde_r_A', 'Sign_r_A', 'Mundbild_Mundgestik_A', 'Deutsche_Übersetzung_B', 'Translation_into_English_B', 'Lexem_Gebärde_r_B', 'Lexeme_Sign_r_B', 'Gebärde_r_B', 'Sign_r_B', 'Lexem_Gebärde_l_B', 'Lexeme_Sign_l_B', 'Gebärde_l_B', 'Sign_l_B', 'Mundbild_Mundgestik_B', 'Moderator', 'Translation_into_English_Mod'])

# %% [markdown]
# Based on the documentation and looking at these print outs, it seems Lexem_Gebärde and Gebärde are probably
# the most relevant tiers. A/B refers to the person doing the signing (2 person dialogues) and l and r
# refer to the hand used for the gesture.

# %%
"""
prints annotations of each identified tier.
"""

eaf = pympi.Elan.Eaf(os.path.join(directory, files[0]))

tier_name = 'Lexem_Gebärde_r_A'
annotations = eaf.get_annotation_data_for_tier(tier_name)

print(f"Annotations from {tier_name}:\n{annotations}")

tier_name = 'Lexem_Gebärde_l_A'
annotations = eaf.get_annotation_data_for_tier(tier_name)

print(f"\nAnnotations from {tier_name}:\n{annotations}")

eaf = pympi.Elan.Eaf(os.path.join(directory, files[0]))

tier_name = 'Lexem_Gebärde_r_B'
annotations = eaf.get_annotation_data_for_tier(tier_name)

print(f"\nAnnotations from {tier_name}:\n{annotations}")

tier_name = 'Lexem_Gebärde_l_B'
annotations = eaf.get_annotation_data_for_tier(tier_name)

print(f"\nAnnotations from {tier_name}:\n{annotations}")
# Out:
# Annotations from Lexem_Gebärde_r_A:
# [(500, 660, 'ICH1'), (780, 1020, 'GEWESEN1'), (1060, 1860, 'VERKEHR1B*'), (2020, 2540, '$INDEX1'), (2660, 2780, '$NUM-EINS-BIS-ZEHN1A:1d'), (2900, 4140, 'FAHREN-LENKRAD1^*'), (4220, 4340, 'ICH1'), (4500, 4700, 'ÜBER1'), (4700, 4820, '$NUM-EINS-BIS-ZEHN1A:
430540, 430660, '$INDEX1*'), (431040, 431260, 'STUNDE1A*'), (431620, 431740, 'ZUERST1A'), (432740, 433240, 'REIHE1^*'), (433560, 433700, '$NUM-EINS-BIS-ZEHN1A:2d'), (433760, 433880, '$NUM-EINS-BIS-ZEHN1A:3d'), (434000, 434660, 'REIHE1^*'), (434900, 434980, '$INDEX1*'), (436060, 436520, 'SEHR-VIEL2'), (436620, 436680, '$INDEX1'), (436780, 436880, 'WAS1A*'), (437420, 437640, 'SEHR-VIEL2*'), (438160, 438280, 'ICH1'), (438720, 438780, 'ICH1'), (439200, 439440, 'MEIN1*'), (439900, 440340, 'ABHOLEN1*'), (440660, 440900, 'GRUND4A'), (440980, 441060, 'ICH1*'), (441880, 441980, '$INDEX1'), (443080, 443380, 'ABHOLEN1*'), (443840, 444020, 'GUT1'), (444360, 444460, '$INDEX1'), (444960, 445240, 'WARTEN1A'), (445340, 445440, 'KOMMEN1*'), (445520, 445820, 'WARTEN1A'), (445920, 446100, '$INDEX1'), (446360, 448800, '$PROD*'), (449100, 449220, 'FERTIG1A*'), (449420, 449520, 'ICH1'), (451860, 451960, 'ICH1'), (452060, 452540, '$PROD*'), (452740, 452960, 'SCHLIESSEN1*'), (453360, 453480, 'TYPISCH1*'), (455240, 455420, 'KLAR1B*'), (457720, 457920, 'FERTIG1B'), (458300, 458480, '$PROD*'), (459300, 459560, 'KOMMEN-AUFFORDERN1*'), (460000, 460240, 'LESEN-BUCH1A^*'), (460440, 460660, 'LOS-START4'), (461180, 461300, 'ICH1'), (463400, 463480, '$INDEX1'), (463600, 463740, 'KÖRPER1^*'), (464520, 464900, 'ERSTES-MAL3A'), (465700, 465960, 'BIS-HEUTE1B^'), (466460, 466720, 'STRASSE4*'), (467400, 467500, '$INDEX1'), (467700, 467840, 'ERSTES-MAL3A'), (468580, 468680, '$GEST^'), (469680, 469760, '$INDEX1'), (469880, 469960, 'ICH1'), (470580, 470680, 'ICH1'), (471580, 471740, '$INDEX1*'), (471940, 47 ...

# %%
tier_name = 'Gebärde_r_A'
try:
    annotations = eaf.get_annotation_data_for_tier(tier_name)
    print(f"Annotations from {tier_name}:\n{annotations}")
except KeyError:
    print(f"\n{tier_name}: Key Not Found.")
          
tier_name = 'Gebärde_l_A'
try:
    annotations = eaf.get_annotation_data_for_tier(tier_name)
    print(f"\nAnnotations from {tier_name}:\n{annotations}")
except KeyError:
    print(f"\n{tier_name}: Key Not Found.")
          
tier_name = 'Gebärde_r_B'
try:
    annotations = eaf.get_annotation_data_for_tier(tier_name)
    print(f"\nAnnotations from {tier_name}:\n{annotations}")
except KeyError:
    print(f"\n{tier_name}: Key Not Found.")

tier_name = 'Gebärde_l_B'
try:
    annotations = eaf.get_annotation_data_for_tier(tier_name)
    print(f"\nAnnotations from {tier_name}:\n{annotations}")
except KeyError:
    print(f"\n{tier_name}: Key Not Found.")
# Out:
# Annotations from Gebärde_r_A:
# [(500, 660, 'ICH1^', 'ICH1'), (780, 1020, 'GEWESEN1^', 'GEWESEN1'), (1060, 1860, 'VERKEHR1B^*', 'VERKEHR1B*'), (2020, 2540, '$INDEX1^', '$INDEX1'), (2660, 2780, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A
1^*', 'UNBEWUSST1*'), (60940, 61060, '$PROD*', '$PROD*'), (61260, 61580, 'AMPEL1^*', 'AMPEL1*'), (61740, 62500, 'NEIN1B^*', 'NEIN1B^*'), (62580, 63420, '$PROD*', '$PROD*'), (64060, 64540, 'RICHTUNG3^', 'GERADEAUS1'), (64780, 65020, '$PROD*', '$PROD*'), (66020, 66740, '$PROD*', '$PROD*'), (69220, 69580, '$PROD*', '$PROD*'), (74700, 75020, '$GEST-OFF1^*', '$GEST-OFF1^*'), (75900, 76340, '$INDEX2^', '$INDEX2'), (77000, 77300, '$PROD*', '$PROD*'), (92700, 93300, '$PROD*', '$PROD*'), (93500, 93700, 'ABER1^*', 'ABER1*'), (112340, 112740, '$PROD*', '$PROD*'), (115340, 115820, 'GUT4^', 'SUPER2'), (115900, 116140, 'VORBEI-ZEIT1^', 'VORBEI-ZEIT1'), (116260, 116460, 'ICH1^', 'ICH1'), (116620, 116780, 'SORGEN-SICH1A^*', 'WUNDERN1*'), (119860, 120660, '$PROD*', '$PROD*'), (130300, 130860, 'UM-DIE-ECKE1^', 'UM-DIE-ECKE1^'), (130980, 131140, 'ICH1^', 'ICH1'), (131300, 131860, 'KREUZ-MACHEN-SEGNEN1A^*', 'FEIERABEND3*'), (132060, 132300, 'NEIN3B^*', 'AUS-VORBEI1*'), (132500, 132740, 'ICH1^', 'ICH1'), (132820, 133220, 'GLÜCK2^*', 'GLÜCK2*'), (133380, 134100, 'ICH1^', 'ICH1'), (137580, 137820, '$PROD*', '$PROD*'), (143340, 143780, 'PARKEN1^', 'AUTO-HALTEN2'), (143840, 143880, 'PARKEN1^', 'AUTO-HALTEN2'), (144360, 144460, 'PARKEN1^', 'AUTO-HALTEN2'), (144900, 145120, 'PARKEN1^', 'AUTO-HALTEN2'), (155640, 155720, 'ICH2^', 'ICH2'), (155800, 155880, '$GEST^', '$GEST^'), (198780, 198880, 'ICH1^*', 'ICH1*'), (201060, 201200, 'MUSS1A^', 'MUSS1'), (201320, 201860, 'DORTHIN1^', 'DORTHIN-GEHEN1'), (203900, 203980, 'MÜHE1^', 'MÜHE1'), (204240, 204400, 'AUF-PERSON1^', 'AUF-PERSON1^'), (211300, 211960, '$GEST-AUFMERKSAMKEIT1^', '$GEST-AUFMERKSAMKEIT1^'), (219180, 219400, '$INDEX1^', '$INDEX1'), (222780, 222920, 'ICH1^', 'ICH1'), (223180, 223340, 'BEKOMMEN1^*', 'BEKOMMEN1*'), (229440, 229700, '$GEST-ABWINKEN1^', '$GEST-ABWINKEN1^'), (238580, 238640, '$PROD*', '$PROD*'), (241560, 241660, 'ERFOLG2^', 'VORTEIL1'), (269280, 269420, '$GEST-ABWINKEN1^', '$GEST-ABWINKEN1^'), (269540, 269700, 'SCHWEIGEN3^', 'LEISE1'), (269780, 269920, '$GEST-AUFMERKSAMKEIT1^', '$GEST-AUFMERKSAMKEIT1^'), (270100, 270620, 'TOLERANT1A^*', 'TOLERANT1*'), (270760, 270980, '$GEST-ABWINKEN1^', '$GEST-ABWINKEN1^'), (283480, 284240, '$PROD*', '$PROD*'), (285580, 286000, 'RICHTUNG3^', 'RICHTUNG3^'), (289280, 289380, '$INDEX1^*', '$INDEX1*'), (289460, 289760, 'FEUER2^*', 'FEUER2^*'), (290100, 290320, '$GEST-ABWINKEN1^', '$GEST-ABWINKEN1^'), (295960, 296100, 'SCHLAFEN1^*', 'SCHLAFEN1A*'), (298260, 298640, '$GEST-ICH-WEISS-NICHT1^', '$GEST-ICH-WEISS-NICHT1^'), (298820, 299220, 'FESTHALTEN4B^*', 'HALTEN-BLATT1A*'), (301000, 301080, '$INDEX1^', '$INDEX1'), (307000, 307120, '$INDEX1^', '$INDEX1'), (307700, 308040, '$INDEX1^', '$INDEX1'), (311500, 311640, '$INDEX1^', '$INDEX1'), (312440, 312800, '$GEST^', '$GEST^'), (352500, 352680, 'FREI4^*', 'WOLLEN8*'), (368060, 368240, 'GEHEN2^', 'GEHEN2A'), (368380, 368520, 'NEIN3A^', 'NICHT3A'), (373100, 373340, '$GEST-ABWINKEN1^', '$GEST-ABWINKEN1^'), (374660, 374840, 'NEIN3A^', 'NICHT3A'), (374920, 375040, 'GEHEN2^', 'GEHEN2A'), (375120, 375280, 'NEIN3A^', 'NICHT3A'), (379940, 380640, 'LÄCHELN1^*', 'LÄCHELN1^*'), (384300, 384440, 'GEHÖREN1^*', 'MEIN1'), (384560, 384660, 'STIMMT1^*', 'WIRKLICH2*'), (384800, 384840, 'STEUERN-LENKRAD1^*', 'AUTO1*'), (384940, 385160, 'GEBEN1A^', 'GEBEN1'), (385260, 385340, 'SOHN-TOCHTER1^', 'SOHN1'), (385540, 385720, 'AUSHALTEN1B^', 'SICH-MIT-ETWAS-ABFINDEN2'), (385720, 385840, 'AUSHALTEN1B^*', 'SICH-MIT-ETWAS-ABFINDEN2*'), (418560, 418840, '$INDEX1^', '$INDEX1'), (591440, 592220, '$INDEX1^', '$INDEX1'), (595840, 596380, 'NACHSCHLAGEN2^*', 'BLÄTTERN3*'), (617020, 617280, 'KANN1^', 'KANN1'), (617440, 617540, 'HAND ...
#
# Annotations from Gebärde_r_B:
# [(6680, 6760, 'HAND-HEBEN3^*', 'ACH-SO2'), (17340, 17680, 'WOFÜR1^*', 'WIESO1*'), (17740, 17840, '$GEST-OFF1^', '$GEST-OFF1^'), (18040, 18320, 'WOFÜR1^*', 'WIESO1*'), (18340, 18380, '$GEST-OFF1^', '$GEST-OFF1^'), (34620, 34700, 'JA1A^', 'JA1A'), (80220, 80560, '$PROD*', '$PROD*'), (80720, 81160, '$PROD*', '$PROD*'), (135140, 135380, 'SPALTUNG1A^*', 'SPALTUNG1A^*'), (135700, 136140, 'KANN1^*', 'MÖGLICH1*'), (136420, 136920, 'SPALTUNG1A^*', 'SPALTUNG1A^*'), (139880, 139980, '$INDEX1^', '$INDEX1'), (140580, 140740, 'AUSFAHRT1^', 'AUSFAHRT1'), (141420, 141680, 'DRUCK-AUF-PERSON1^', 'PFLICHT5'), (141940, 142120, 'AUSFAHRT1^', 'AUSFAHRT1'), (142580, 142700, 'GLEICH1A^*', 'WIE-VERGLEICH3A*'), (144740, 145040, 'NEIN3B^*', 'SCHLUSS1'), (146460, 146700, 'STIMMT1^*', 'STIMMT1B'), (167400, 167480, '$NUM-NULL1B^', '$NUM-NULL1B'), (167580, 167780, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A
'$GEST-ABWINKEN1^', '$GEST-ABWINKEN1^'), (456520, 456660, 'HEBEL6^*', 'HANDBREMSE1*'), (456920, 457280, '$PROD*', '$PROD*'), (458300, 458480, 'DREHEN-FESTHALTEN1^', 'ANMACHEN1'), (458840, 459000, 'NEIN3B^*', 'SCHLUSS1'), (461600, 461800, 'SCHLIESSEN1^*', 'SCHLIESSEN1*'), (462100, 463080, '$PROD*', '$PROD*'), (463860, 464180, 'AUTOBAHN1^*', 'AUTOBAHN1*'), (465080, 465480, 'AUTOBAHN1^*', 'AUTOBAHN1*'), (466080, 466180, 'FAHREN1^*', 'FAHREN1*'), (466880, 467000, 'FLACH3A^*', 'LAND3A*'), (467120, 467260, 'PARALLEL1B^', 'STRASSE1A'), (467940, 468020, 'AUTOBAHN1^*', 'AUTOBAHN1*'), (468220, 468500, 'LERNEN1^', 'LERNEN1'), (469120, 469340, 'DURCH1^*', 'DURCH1^*'), (470080, 470340, 'AUTOBAHN1^', 'AUTOBAHN1'), (470820, 470920, 'WOHNUNG1A^*', 'WOHNUNG1A*'), (471160, 471400, 'SPITZ-OBEN2A^*', 'HAUS3*'), (476200, 476500, 'PASSIERT3^*', 'PASSIERT3*'), (477880, 477980, '$INDEX1^', '$INDEX1'), (479100, 479380, 'KREUZ3^*', 'KREUZ3*'), (4 ...
#
# Annotations from Gebärde_l_B:
# [(79760, 80120, 'BLITZ-FOTO1^*', 'BLITZ-FOTO1^*'), (134780, 134900, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A:2'), (135480, 135580, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A:2'), (140140, 140360, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A:1d'), (140960, 141100, 'BEDEUTUNG1^', 'BEDEUTUNG1'), (142200, 142280, '$INDEX1^', '$INDEX1'), (142860, 143080, 'REGEL1A^', 'REGEL1A'), (143220, 143500, 'VERSTOSSEN1^', 'VERSTOSSEN1'), (143880, 144100, 'RICHTUNG3^', 'RICHTUNG3^'), (144380, 144500, 'WARUM1^', 'WARUM1'), (170020, 170720, 'DAZU1^*', 'DAZU1*'), (172120, 172340, 'MUSS1A^', 'MUSS1'), (214420, 214700, 'KENNEN1A^', 'KENNEN1A'), (216180, 216840, 'STIMMT1^*', 'STIMMT1B'), (217040, 217400, 'GROSSMAUL1^*', 'GROSSMAUL1*'), (217540, 218020, 'STIMMT1^*', 'RICHTIG1A'), (339640, 339700, 'WEISS1A^*', 'WEISS1A*'), (340120, 340200, '$INDEX1^', '$INDEX1'), (340300, 340420, 'ICH1^', 'ICH1'), (340580, 340640, '$INDEX1^', '$INDEX1'), (341920, 342140, 'STIMMT1^*', 'STIMMT1B'), (343140, 343360, 'STIMMT1^', 'STIMMT1A'), (364400, 364560, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A:2'), (391640, 391700, 'STIMMT1^*', 'STIMMT1A*'), (392840, 392920, '$INDEX1^', '$INDEX1'), (393640, 393780, 'STRENG1^', 'STRENG1'), (395500, 395600, 'HARMLOS1^*', 'HARMLOS1*'), (395680, 395940, '$GEST-ABWINKEN1^', '$GEST-ABWINKEN1^'), (395980, 396100, '$GEST-OFF1^', '$GEST-OFF1^'), (396520, 397000, 'ICH1^*', 'ICH1*'), (400120, 400340, 'STIMMT1^*', 'STIMMT1B'), (401140, 401260, 'SO1^*', 'SO1C*'), (401360, 401420, '$INDEX1^', '$INDEX1'), (401540, 401800, 'JUNG1^', 'JUNG1'), (402620, 403140, 'STRENG1^*', 'STRENG1*'), (403220, 403360, 'VORNE1^*', 'VORNE1^*'), (403520, 403620, 'FALTE-WANGE2A^*', 'ALT5A*'), (405300, 405420, '$INDEX1^', '$INDEX1'), (406100, 406200, 'HAUPT1B^', 'HAUPT1B^'), (406260, 406400, 'ALLE2A^', 'ALLE2A'), (406620, 406800, '$GEST-ABWINKEN1^*', '$GEST-ABWINKEN1^*'), (407160, 407480, 'ICH1^*', 'ICH1*'), (408040, 408160, 'SCHREIBEN1A^*', 'SCHULE1A*'), (408300, 408460, 'MUSS1A^', 'AUCH3A'), (408600, 408680, 'ICH1^', 'ICH1'), (408780, 408920, 'EINTRETEN1^*', 'EINSTEIGEN1*'), (409100, 409660, 'HIN-UND-HER1^*', 'HIN-UND-HER1*'), (409740, 409880, 'BREMEN1^*', 'BREMEN1*'), (410240, 410340, 'ICH1^', 'ICH1'), (410420, 410680, 'NAHE2A^*', 'NAHE2A*'), (410860, 411060, 'HIER-JETZT1^', 'HIER1'), (411420, 411620, 'HÖREND1A^', 'HÖREND1A'), (411860, 411980, 'SCHREIBEN1A^', 'SCHULE1A'), (412100, 412300, 'HÖREND1A^', 'HÖREND1A'), (412440, 412600, 'GEHÖREN1^*', 'SEIN-IHR1'), (412880, 413000, 'ICH1^', 'ICH1'), (413580, 413640, '$INDEX1^', '$INDEX1'), (414620, 414840, '$INDEX1^', '$INDEX1'), (415360, 415880, 'GESTIK1^', 'GESTIK1'), (416140, 416280, '$GEST-ABWINKEN1^*', '$GEST-ABWINKEN1^*'), (416860, 417040, 'HAUPT1B^', 'HAUPTSACHE1B'), (417620, 418040, 'HÖREND1A^*', 'HÖREND1A*'), (420260, 420380, '$INDEX1^', '$INDEX1'), (420580, 420680, 'ICH1^', 'ICH1'), (420900, 421200, '$NUM-ORD1^*', '$NUM-ORD1:1'), (421440, 421520, 'ICH1^', 'ICH1'), (421820, 422180, '$NUM-ORD1^*', '$NUM-ORD1:1'), (422640, 423140, '$INDEX1^', '$INDEX1'), (424100, 424180, 'ICH1^', 'ICH1'), (424340, 424540, '$NUM-ORD1^*', '$NUM-ORD1:1'), (424660, 424720, 'ICH1^', 'ICH1'), (424980, 425180, 'EINTRETEN1^*', 'EINSTEIGEN1*'), (425720, 425920, 'MUSS1A^', 'AUCH3A'), (427040, 427300, 'HAUPT1A^', 'ZUERST1A'), (427620, 427800, 'VORSTELLUNG1A^', 'THEORIE1A'), (427900, 428180, 'SCHREIBEN1A^*', 'SCHREIBEN1A*'), (429340, 429440, 'DANACH1A^', 'DANN1A'), (429600, 430160, 'FAHREN-LENKRAD1^*', 'FAHREN-LENKRAD1^*'), (430540, 430660, '$INDEX1^*', '$INDEX1*'), (431040, 431260, 'ZEIT5A^*', 'STUNDE1A*'), (431620, 431740, 'HAUPT1A^', 'ZUERST1A'), (432740, 433240, 'REIHE1^*', 'REIHE1^*'), (433560, 433700, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A:2d'), (433760, 433880, '$NUM-EINS-BIS-ZEHN1A^*', '$NUM-EINS-BIS-ZEHN1A:3d'), (434000, 434660, 'REIHE1^*', 'REIHE1^*'), (434900, 434980, '$INDEX1^*', '$INDEX1*'), (436060, 436520, 'SEHR-VIEL1^', 'SEHR-VIEL2'), (436620, 436680, '$INDEX1^', '$INDEX1'), (436780, 436880, 'WAS1A^*' ...

# %% [markdown]
# It looks like either one of these pairs of tiers could be used, so I want to check which pair of tier names
# is present in all the annotations that I currently have.

# %%
tiers_present = []

tier_checks = ['Gebärde_r_A', 'Gebärde_l_A', 'Gebärde_r_B', 'Gebärde_l_B']

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    tier_names = eaf.get_tier_names()

    if all(x in tier_names for x in tier_checks):
        tiers_present.append(True)
    else:
        tiers_present.append(False)

print(f"{tier_checks} present in all files: {all(tiers_present)}")

tiers_present = []

tier_checks = ['Lexem_Gebärde_r_A', 'Lexem_Gebärde_l_A', 'Lexem_Gebärde_r_B', 'Lexem_Gebärde_l_B']

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    tier_names = eaf.get_tier_names()

    if all(x in tier_names for x in tier_checks):
        tiers_present.append(True)
    else:
        tiers_present.append(False)

print(f"{tier_checks} present in all files: {all(tiers_present)}")

tiers_present = []

tier_checks = ['Gebärde_r_A', 'Gebärde_r_B']

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    tier_names = eaf.get_tier_names()

    if all(x in tier_names for x in tier_checks):
        tiers_present.append(True)
    else:
        tiers_present.append(False)

print(f"{tier_checks} present in all files: {all(tiers_present)}")

tiers_present = []

tier_checks = ['Lexem_Gebärde_r_A', 'Lexem_Gebärde_r_B']

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    tier_names = eaf.get_tier_names()

    if all(x in tier_names for x in tier_checks):
        tiers_present.append(True)
    else:
        tiers_present.append(False)

print(f"{tier_checks} present in all files: {all(tiers_present)}")

tiers_present = []

tier_checks = ['Gebärde_l_A', 'Gebärde_l_B']

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    tier_names = eaf.get_tier_names()

    if all(x in tier_names for x in tier_checks):
        tiers_present.append(True)
    else:
        tiers_present.append(False)

print(f"{tier_checks} present in all files: {all(tiers_present)}")

tiers_present = []

tier_checks = ['Lexem_Gebärde_l_A', 'Lexem_Gebärde_l_B']

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    tier_names = eaf.get_tier_names()

    if all(x in tier_names for x in tier_checks):
        tiers_present.append(True)
    else:
        tiers_present.append(False)

print(f"{tier_checks} present in all files: {all(tiers_present)}")
# Out:
# ['Gebärde_r_A', 'Gebärde_l_A', 'Gebärde_r_B', 'Gebärde_l_B'] present in all files: False
# ['Lexem_Gebärde_r_A', 'Lexem_Gebärde_l_A', 'Lexem_Gebärde_r_B', 'Lexem_Gebärde_l_B'] present in all files: False
# ['Gebärde_r_A', 'Gebärde_r_B'] present in all files: True
# ['Lexem_Gebärde_r_A', 'Lexem_Gebärde_r_B'] present in all files: True
# ['Gebärde_l_A', 'Gebärde_l_B'] present in all files: False
# ['Lexem_Gebärde_l_A', 'Lexem_Gebärde_l_B'] present in all files: False

# %% [markdown]
# The only thing present in all .eaf files are the right hand gestures, which makes sense
# as it is the dominant hand.
#
# Next, I remove the endings of the lexemes in order to make sure that I can get an accurate
# lexeme count for each of the signs.

# %%
def extract_base_lexeme(text):
    match = re.match(r'^([A-ZÄÖÜß]+)', text.upper())
    return match.group(1) if match else text

# %%
tier_names = ['Lexem_Gebärde_r_A', 'Lexem_Gebärde_r_B', 'Lexem_Gebärde_l_A', 'Lexem_Gebärde_l_B']
word_counts = {}

for file in files:
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))
    
    for tier_name in tier_names:
        if tier_name not in eaf.get_tier_names():
            continue

        annotations = eaf.get_annotation_data_for_tier(tier_name)
        
        for values in annotations:
            value = values[2]
            
            if value.startswith('$'):
                continue
            
            lexeme = extract_base_lexeme(value)
            word_counts[lexeme] = word_counts.get(lexeme, 0) + 1

# %%
items = [item for item in word_counts.items()]
counts = pd.DataFrame(items, columns = ['Lexeme', 'Count']).sort_values(by = ['Count'], ascending = False)
print(counts.head(20))
# Out:
#        Lexeme  Count
# 0         ICH   1595
# 12      NICHT    204
# 77       TAUB    168
# 199       GUT    151
# 53        WIE    143
# 183      AUCH    130
# 163      ALLE    119
# 82     WISSEN    119
# 100        DU    113
# 204    FERTIG    112
# 113      NEIN    105
# 9       SAGEN    102
# 5       SEHEN    102
# 299  GEBÄRDEN    102
# 137      MUSS    101
# 66     STIMMT     97
# 61        WAS     96
# 168    KOMMEN     92
# 54   ARBEITEN     90
# 58       VIEL     90

# %% [markdown]
# There seems to be sufficient data to train the model on a few key words of choice.
# I will take the top 10 words for use in training. I am saving it as a list that
# I will convert to a set when searching for start and stop times so that I can
# get an O(1) lookup time.

# %%
words = counts['Lexeme'].iloc[0:10].to_list()

print(words)

with open('../data/word_set.json', 'w') as f:
    json.dump(words, f)
# Out:
# ['ICH', 'NICHT', 'TAUB', 'GUT', 'WIE', 'AUCH', 'ALLE', 'WISSEN', 'DU', 'FERTIG']

# %% [markdown]
# The next step is to extract all the start and stop times for the gestures and the gloss for
# the gestures so that I can trim clips and create the dataset for model training.

# %%
word_set = set(words)
tier_names = ['Lexem_Gebärde_r_A', 'Lexem_Gebärde_r_B', 'Lexem_Gebärde_l_A', 'Lexem_Gebärde_l_B']
extracted_values = []

directory = '../data/raw/dialogues'
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f)) and f.endswith('.eaf')]

for file in files:

    filename = os.path.splitext(file)[0]
    eaf = pympi.Elan.Eaf(os.path.join(directory, file))

    for tier_name in tier_names:

        ich_count = 0

        if tier_name[-1] == 'A':
            extension = '_1a1.mp4'
        else:
            extension = '_1b1.mp4'

        if tier_name not in eaf.get_tier_names():
            continue 

        annotations = eaf.get_annotation_data_for_tier(tier_name)

        for values in annotations:
            value = values[2]

            if value.startswith('$'):
                continue

            lexeme = extract_base_lexeme(value)

            if lexeme not in word_set:
                continue
            
            if lexeme == 'ICH':
                ich_count += 1

                if ich_count > 5:
                    continue

            start = values[0]
            end = values[1]

            extracted_values.append((filename + extension, start, end, lexeme))

dataset = pd.DataFrame(extracted_values, columns = ['filename', 'start', 'end', 'lexeme'])
dataset.to_csv('../data/start_end_times.csv', index = False)

# %% [markdown]
# I want to check the value counts for these items to make sure there is some balance.
# In the above code I basically put a cap on how much 'ICH' clips there could be because
# there are way more total 'ICH' and having such a strong imbalance could cause
# overgeneralizations. Below I simply check the counts to see they are more balanced.

# %%
counts = dataset.value_counts(subset = 'lexeme')

print(counts)
# Out:
# lexeme
# NICHT     204
# TAUB      168
# ICH       164
# GUT       151
# WIE       143
# AUCH      130
# ALLE      119
# WISSEN    119
# DU        113
# FERTIG    112
# Name: count, dtype: int64

# %% [markdown]
# Now I have generated a list of all the filenames, start and end times, and the lexeme of interest,
# I can begin the cutting part of the preprocessing. For this, I use 'ffmpeg-python'.

# %%
df = pd.read_csv('../data/start_end_times.csv')

video_dir = '../data/raw/dialogues'
output_dir = '../data/clips'

os.makedirs(output_dir, exist_ok=True)

for idx, row in df.iterrows():

    buffer = 0.2

    input_file = os.path.join(video_dir, row['filename'])
    start = (row['start'] / 1000) - buffer
    end = (row['end'] / 1000) + buffer
    lexeme = row['lexeme']

    base_name = os.path.splitext(row['filename'])[0]
    output_filename = f"{base_name}_{start:.3f}_{lexeme}.mp4"
    output_path = os.path.join(output_dir, output_filename)

    if os.path.exists(output_path):
        continue

    try:
        with VideoFileClip(input_file) as video:
            clip = video.subclipped(start, end)
            clip.write_videofile(output_path, codec = 'libx264', audio_codec = 'aac', logger = None)
    except Exception as e:
        print(f"Error cutting {input_file} at {start}-{end}: {e}")
